# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
tips_df = sns.load_dataset("tips")
print(tips_df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sorted_df = tips_df.sort_values(by = "total_bill")

# %%
sns.lineplot(x="total_bill", y="tip", data=sorted_tips)
plt.title("Pratik")
plt.show()

# %%
fmri_df = sns.load_dataset("fmri")

# %%
fmri_df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
tips_df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Create a bar plot
sns.barplot(x="smoker", y="tip", data=tips_df , hue="smoker")

# Display the plot
plt.show()

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.groupby('smoker')['tip'].mean()
# Out:
# C:\Users\deshm\AppData\Local\Temp\ipykernel_16080\3502051815.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_df.groupby('smoker')['tip'].mean()
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
# Create a count plot
sns.countplot(x="day", data=tips_df , hue="smoker")

# Add a title
plt.title("Number of Meals Served per Day")

# Display the plot
plt.show()

# %%
# Create a box plot
sns.boxplot(x="day", y="total_bill", data=tips_df)

# Add a title
plt.title("Distribution of Total Bill for Each Day")

# Display the plot
plt.show()

# %%
# Create a violin plot
sns.violinplot(x="day", y="total_bill", data=tips_df)

# Add a title
plt.title("Distribution of Total Bill for Each Day")

# Display the plot
plt.show()
